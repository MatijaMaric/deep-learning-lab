# %%
import numpy as np
from dataset import Dataset
from rnn import RNN
from model import run_language_model

# %%
dataset = Dataset()
dataset.preprocess("data/selected_conversations.txt")
dataset.create_minibatches()

rnn = run_language_model(dataset, 50, sequence_length=dataset.sequence_length, seed="HAN:\nIs that good or bad?\n\n", sample_every=1000)
# Out:
# Batch: 0/616, loss: 4.324956, epoch: 0/50, avg loss: 0.432496
# ...
# HAN:
# Is that good or bad?
#
# rmfTrJbez7rrZu1eMTFxxprlvSVFGlBpem.0Zw1VsGtzF1REhoL9TMVsGhLF:N5A8ssAnaiv6rmEREzu71c4sVWo9akVitPwN!:x
#  QBjQyD evvUaZuwrl  YWQy4 DtcfR9k!ILfHSx
# 98836:7J
# 8i  uWrUurrn5XT7ueOftN
# ...
# Batch: 384/616, loss: 2.011064, epoch: 1/50, avg loss: 1.954202
# ...
# HAN:
# Is that good or bad?
#
# DOFFFUSA:
# Cheve dover.
#
# CKATESTEY:
# Ghaik and yon are womd gut I goiie bodithittr the blinged the gig winct tuck.
#
# FRED.
#
# JOgNEF GOUDY:
# Ood wave I Dally!
#
# CAWHUNA:
# He us an.
# ...
# Batch: 152/616, loss: 1.885062, epoch: 3/50, avg loss: 1.883556
# ...
# HAN:
# Is that good or bad?
#
# MR. IATOR:
# To MO LuUherenis Keren't iolhen I Cye prontce that, oreth bef think
#
# MR. HRAEPE:
# Hongors ran do a the is ictor you or sho bichth not a thought the elpa onr? I'll.
# ...
# Batch: 536/616, loss: 1.858934, epoch: 4/50, avg loss: 1.786785
# ...
# HAN:
# Is that good or bad?
#
# DOR:
# Are abeipenvon dool?
#
# KARMHESA:
# ...
